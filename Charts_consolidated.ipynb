# %%
import pandas as pd
import numpy as np
from scipy.stats import sem, ttest_ind, f_oneway, linregress, stats
from matplotlib import pyplot as plt

from re import sub
from decimal import Decimal
from textwrap import wrap

# %matplotlib notebook

# %%
# Dhruv's Code ---------------------------------------------------------------------------------------------
# Figure out the following: Biggest/most popular Sector by State
# Compare that by the # of employees per sector

#Bar graph for both above
#x axis: Sector Names

#Define biggest/most popular sector by total number of employees in each sector

# %%
df_final_5 = pd.read_csv("CSV_file/Final_Dataframe.csv", encoding="utf-8")

# %%
plt.figure(figsize=(30,30))
plt.barh(df_final_5["State & Sector"], df_final_5["# Employees"])
plt.xticks(fontsize = 20)
plt.yticks(fontsize = 20)
plt.xlabel("# of Employees", fontsize=20)
plt.title("Biggest Sector per each State (by # of employees)", fontsize=25)
plt.savefig("Images/SectorPopularityPerState.png")
# Out:
# <img src="data:image/png;base64,..." width="3000">

# %%
# Yujin's Code ---------------------------------------------------------------------------------------------

# %%
company_df = pd.read_csv("Resources/company_data.csv")
company_df.head()
# Out:
#   Symbol                 Name                  Sector   Price  Price/Earnings  \
# 0    MMM           3M Company             Industrials  222.89           24.31
# 1    AOS      A.O. Smith Corp             Industrials   60.24           27.76
# 2    ABT  Abbott Laboratories             Health Care   56.27           22.51
# 3   ABBV          AbbVie Inc.             Health Care  108.48           19.41
# 4    ACN        Accenture plc  Information Technology  150.51           25.47
#
#    Dividend Yield  Earnings/Share  52 Week Low  52 Week High    Market Cap  \
# 0        2.332862            7.92       259.77       175.490  138721055226
# 1        1.147959            1.70        68.39        48.925   10783419933
# 2        1.908982            0.26        64.60        42.280  102121042306
# 3        2.499560            3.29       125.86        60.050  181386347059
# 4        1.714470            5.44       162.60       114.820   98765855553
#
#          EBITDA  Price/Sales  Price/Book  \
# 0  9.048000e+09     4.390271       11.34
# 1  6.010000e+08     3.575483        6.35
# 2  5.744000e+09     3.740480        3.19
# 3  1.031000e+10     6.291571       26.14
# 4  5.643228e+09     2.604117       10.62
#
#                                          SEC Filings
# 0  http://www.sec.gov/cgi-bin/browse-edgar?action...
# 1  http://www.sec.gov/cgi-bin/browse-edgar?action...
# 2  http://www.sec.gov/cgi-bin/browse-edgar?action...
# 3  http://www.sec.gov/cgi-bin/browse-edgar?action...
# 4  http://www.sec.gov/cgi-bin/browse-edgar?action...

# %%
#Number of Top 500 S&P Companies in each Industry Sector

company_group = company_df.groupby("Sector").count()
company_group[["Symbol"]]
# Out:
#                             Symbol
# Sector
# Consumer Discretionary          84
# Consumer Staples                34
# Energy                          32
# Financials                      68
# Health Care                     61
# Industrials                     67
# Information Technology          70
# Materials                       25
# Real Estate                     33
# Telecommunication Services       3
# Utilities                       28

# %%
#how many computer/math employees there are per state

math_emp = "Resources/BLS_math_employees.csv"
math_df = pd.read_csv(math_emp, encoding="utf-8")
math_df = math_df.sort_values("Mean_wage_yr", ascending=False)
math_df = math_df[["State", "Mean_wage_yr"]]
math_top_5 = math_df.head()
math_top_5
# Out:
#    State  Mean_wage_yr
# 50    WA        108660
# 8     DC        108600
# 4     CA        108190
# 49    VA        102430
# 31    NJ        101390

# %%
fig, ax = plt.subplots()
# x_axis = reformat_df.index

title = ax.set_title("\n".join(wrap("Top 5 States with Highest Average Wages for Computational Employees", 60)), fontweight="bold")

# fig.suptitle("Top 5 States with Highest Average Wages for Computational Employees")
# ax.set_xlabel("Number of Fortune 500 Companies per State")
ax.set_ylabel("Average Wage of Computational Employees")

# ax.set_ylim(30,75)
# ax.grid()

ax.bar(math_top_5["State"], math_top_5["Mean_wage_yr"])
plt.savefig("Images/top5highestavgwage.png")
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
fortune_1000 = pd.read_csv("Resources/fortune_1000_part.csv")
revenue_int = []
for x in fortune_1000["Revenues ($M)"]:
    revenue_int.append(float(x.replace("$","").replace(",","").replace(" ","")))
fortune_1000["Revenue as Int"] = revenue_int
fortune_1000.loc[fortune_1000["State"] == "Michigan", "State"] = "MI"
fortune_1000
# Out:
#                              Company Revenues ($M) Profits ($M)  Assets ($M)  \
# 0                            Walmart     $500,343    $9,862.00     $204,522
# 1                        Exxon Mobil     $244,363   $19,710.00     $348,691
# 2                 Berkshire Hathaway     $242,137   $44,940.00     $702,095
# 3                              Apple     $229,234   $48,351.00     $375,319
# 4                 UnitedHealth Group     $201,159   $10,558.00     $139,058
# 5                           McKesson     $198,533    $5,070.00      $60,969
# 6                         CVS Health     $184,765    $6,622.00      $95,131
# 7                         Amazon.com     $177,866    $3,033.00     $131,310
# 8                               AT&T     $160,546   $29,450.00     $444,097
# 9                     General Motors     $157,311   ($3,864.00)    $212,482
# 10                        Ford Motor     $156,776    $7,602.00     $257,808
# 11                 AmerisourceBergen     $153,144      $364.50      $35,317
# 12                           Chevron     $134,533    $9,195.00     $253,806
# 13                   Cardinal Health     $129,976    $1,288.00      $40,112
# 14                            Costco     $129,025    $2,679.00      $36,347
# 15                           Verizon     $126,034   $30,101.00     $257,143
# 16                            Kroger     $122,662    $1,907.00      $37,197
# 17                  General Electric     $122,274   ($5,786.00)    $377,945
# 18          Walgreens Boots Alliance     $118,214    $4,078.00      $66,009
# 19                    JPMorgan Chase     $113,899   $24,441.00   $2,533,600
# 20                        Fannie Mae     $112,394    $2,463.00   $3,345,529
# 21                          Alphabet     $110,855   $12,662.00     $197,295
# 22                        Home Depot     $100,904    $8,630.00      $44,529
# 23             Bank of America Corp.     $100,264   $18,232.00   $2,281,234
# 24           Express Scripts Holding     $100,065    $4,517.40      $54,256
# 25                       Wells Fargo      $97,741   $22,183.00   $1,951,757
# 26                            Boeing      $93,392    $8,197.00      $92,333
# 27                       Phillips 66      $91,568    $5,106.00      $54,371
# 28                            Anthem      $90,040    $3,842.80      $70,540
# 29                         Microsoft      $89,950   $21,204.00     $241,086
# ..                               ...           ...          ...          ...
# 970            Nuance Communications       $1,939     ($151.00)      $5,932
# 971                      Finish Line       $1,934      ($18.20)        $747
# 972                       TransUnion       $1,934      $441.20       $5,119
# 973                       ServiceNow       $1,933     ($149.10)      $3,398
# 974                 Summit Materials       $1,933      $121.80       $3,787
# 975                Engility Holdings       $1,932      ($35.20)      $2,026
# 976              Ferrellgas Partners       $1,930      ($54.20)      $1,610
# 977        Interactive Brokers Group       $1,927       $76.00      $61,162
# 978                           Stepan       $1,925       $91.60       $1,471
# 979        Oceaneering International       $1,922      $166.40       $3,024
# 980                   Cimarex Energy       $1,918      $494.30       $5,043
# 981                          Rexnord       $1,918       $74.10       $3,539
# 982                 Beazer Homes USA       $1,916       $31.80       $2,221
# 983                  MKS Instruments       $1,916      $339.10       $2,414
# 984                     Vail Resorts       $1,907      $210.60       $4,111
# 985             Ohio National Mutual       $1,907       $25.90      $41,843
# 986                         TopBuild       $1,906      $158.10       $1,750
# 987                    Brown & Brown       $1,881      $399.60       $5,748
# 988      Aerojet Rocketdyne Holdings       $1,877       ($9.20)      $2,259
# 989         Barnes & Noble Education       $1,874        $5.40       $1,300
# 990         Superior Energy Services       $1,874     ($205.90)      $3,110
# 991                 VeriFone Systems       $1,871     ($173.80)      $2,322
# 992                  Childrens Place       $1,870       $84.70         $940
# 993                    Tribune Media       $1,867      $194.10       $8,169
# 994        Healthcare Services Group       $1,866       $88.20         $676
# 995         SiteOne Landscape Supply       $1,862       $54.60         $911
# 996  Charles River Laboratories Intl       $1,858      $123.40       $2,930
# 997                        CoreLogic       $1,851      $152.20       $4,077
# 998                     Ensign Group       $1,849       $40.50       $1,102
# 999                              HCP       $1,848      $414.20      $14,089
#
#      Employees                          Sector  \
# 0    2,300,000                       Retailing
# 1       71,200                          Energy
# 2      377,000                      Financials
# 3      123,000                      Technology
# 4      260,000                     Health Care
# 5       64,500                     Wholesalers
# 6      203,000                     Health Care
# 7      566,000                       Retailing
# 8      254,000              Telecommunications
# 9      180,000         Motor Vehicles &  Parts
# 10     202,000         Motor Vehicles &  Parts
# 11      19,500                     Wholesalers
# 12      51,900                          Energy
# 13      40,400                     Wholesalers
# 14     182,000                       Retailing
# 15     155,400              Telecommunications
# 16     449,000             Food &  Drug Stores
# 17     313,000                     Industrials
# 18     290,000             Food &  Drug Stores
# 19     252,539                      Financials
# 20       7,200                      Financials
# 21      80,110                      Technology
# 22     413,000                       Retailing
# 23     209,376                      Financials
# 24      26,600                     Health Care
# 25     262,700                      Financials
# 26     140,800            Aerospace &  Defense
# 27      14,600                          Energy
# 28      56,000                     Health Care
# 29     124,000                      Technology
# ..         ...                             ...
# 970     11,600                      Technology
# 971      8,200                       Retailing
# 972      5,100               Business Services
# 973      6,222                      Technology
# 974      6,000                       Materials
# 975      8,700            Aerospace &  Defense
# 976      3,891                          Energy
# 977      1,228                      Financials
# 978      2,096                       Chemicals
# 979      8,200                          Energy
# 980        910                          Energy
# 981      8,000                     Industrials
# 982      1,100     Engineering &  Construction
# 983      4,923                      Technology
# 984     20,150  Hotels, Restaurants &  Leisure
# 985      1,300                      Financials
# 986      8,400     Engineering &  Construction
# 987      8,491                      Financials
# 988      5,157            Aerospace &  Defense
# 989     13,375                       Retailing
# 990      6,400                          Energy
# 991      5,600                      Technology
# 992      9,800                       Retailing
# 993      6,000                           Media
# 994     55,000                     Health Care
# 995      3,664                     Wholesalers
# 996     11,800                     Health Care
# 997      5,900               Business Services
# 998     21,301                     Health Care
# 999        190                      Financials
#
#                                            Industry           City State  \
# 0                             General Merchandisers    Bentonville    AR
# 1                                Petroleum Refining         Irving    TX
# 2          Insurance: Property and Casualty (Stock)          Omaha    NE
# 3                       Computers, Office Equipment      Cupertino    CA
# 4           Health Care: Insurance and Managed Care     Minnetonka    MN
# 5                          Wholesalers: Health Care             SF    CA
# 6          Health Care: Pharmacy and Other Services     Woonsocket    RI
# 7                   Internet Services and Retailing        Seattle    WA
# 8                                Telecommunications         Dallas    TX
# 9                          Motor Vehicles and Parts        Detroit    MI
# 10                         Motor Vehicles and Parts       Dearborn    MI
# 11                         Wholesalers: Health Care   Chesterbrook    PA
# 12                               Petroleum Refining      San Ramon    CA
# 13                         Wholesalers: Health Care         Dublin    OH
# 14                            General Merchandisers       Issaquah    WA
# 15                               Telecommunications       New York    NY
# 16                             Food and Drug Stores     Cincinnati    OH
# 17                             Industrial Machinery         Boston    MA
# 18                             Food and Drug Stores      Deerfield    IL
# 19                                 Commercial Banks       New York    NY
# 20                           Diversified Financials    Leavenworth    WA
# 21                  Internet Services and Retailing  Mountain View    CA
# 22                       Specialty Retailers: Other        Atlanta    GA
# 23                                 Commercial Banks      Charlotte    NC
# 24         Health Care: Pharmacy and Other Services      St. Louis    MO
# 25                                 Commercial Banks             SF    CA
# 26                            Aerospace and Defense        Chicago    IL
# 27                               Petroleum Refining        Houston    TX
# 28          Health Care: Insurance and Managed Care   Indianapolis    IN
# 29                                Computer Software        Redmond    WA
# ..                                              ...            ...   ...
# 970                               Computer Software     Burlington    MA
# 971                    Specialty Retailers: Apparel   Indianapolis    IN
# 972                         Financial Data Services        Chicago    IL
# 973                               Computer Software    Santa Clara    CA
# 974                       Building Materials, Glass         Denver    CO
# 975                           Aerospace and Defense      Chantilly    VA
# 976                                          Energy  Overland Park    KS
# 977                                      Securities      Greenwich    CT
# 978                                       Chemicals     Northfield    IL
# 979                 Oil and Gas Equipment, Services        Houston    TX
# 980                    Mining, Crude-Oil Production         Denver    CO
# 981                            Industrial Machinery      Milwaukee    WI
# 982                                    Homebuilders        Atlanta    GA
# 983  Semiconductors and Other Electronic Components        Andover    MA
# 984                        Hotels, Casinos, Resorts     Broomfield    CO
# 985                 Insurance: Life, Health (stock)     Cincinnati    OH
# 986                       Engineering, Construction  Daytona Beach    FL
# 987        Insurance: Property and Casualty (Stock)  Daytona Beach    FL
# 988                           Aerospace and Defense     El Segundo    CA
# 989                      Specialty Retailers: Other       Bernards    NJ
# 990                 Oil and Gas Equipment, Services        Houston    TX
# 991                         Financial Data Services       San Jose    CA
# 992                    Specialty Retailers: Apparel       Secaucus    NJ
# 993                                   Entertainment        Chicago    IL
# 994        Health Care: Pharmacy and Other Services       Bensalem    PA
# 995                        Wholesalers: Diversified        Roswell    GA
# 996        Health Care: Pharmacy and Other Services     Wilmington    MA
# 997                         Financial Data Services         Irvine    CA
# 998                 Health Care: Medical Facilities  Mission Viejo    CA
# 999                                     Real estate         Irvine    CA
#
#      Revenue as Int
# 0          500343.0
# 1          244363.0
# 2          242137.0
# 3          229234.0
# 4          201159.0
# 5          198533.0
# 6          184765.0
# 7          177866.0
# 8          160546.0
# 9          157311.0
# 10         156776.0
# 11         153144.0
# 12         134533.0
# 13         129976.0
# 14         129025.0
# 15         126034.0
# 16         122662.0
# 17         122274.0
# 18         118214.0
# 19         113899.0
# 20         112394.0
# 21         110855.0
# 22         100904.0
# 23         100264.0
# 24         100065.0
# 25          97741.0
# 26          93392.0
# 27          91568.0
# 28          90040.0
# 29          89950.0
# ..              ...
# 970          1939.0
# 971          1934.0
# 972          1934.0
# 973          1933.0
# 974          1933.0
# 975          1932.0
# 976          1930.0
# 977          1927.0
# 978          1925.0
# 979          1922.0
# 980          1918.0
# 981          1918.0
# 982          1916.0
# 983          1916.0
# 984          1907.0
# 985          1907.0
# 986          1906.0
# 987          1881.0
# 988          1877.0
# 989          1874.0
# 990          1874.0
# 991          1871.0
# 992          1870.0
# 993          1867.0
# 994          1866.0
# 995          1862.0
# 996          1858.0
# 997          1851.0
# 998          1849.0
# 999          1848.0
#
# [1000 rows x 10 columns]

# %%
fortune_group = fortune_1000.groupby("State")
fortune_count = fortune_group["Revenue as Int"].count()
fortune_count.sort_values()

state_df = pd.DataFrame(fortune_count)
state_df = state_df.drop(["Puerto Rico"], axis=0)
state_df
# Out:
#        Revenue as Int
# State
# AL                  3
# AR                  8
# AZ                 17
# CA                118
# CO                 19
# CT                 27
# DE                  2
# FL                 35
# GA                 30
# HI                  3
# IA                  6
# ID                  3
# IL                 70
# IN                 17
# KS                  6
# KY                  9
# LA                  3
# MA                 32
# MD                 12
# ME                  1
# MI                 28
# MN                 25
# MO                 23
# MS                  1
# NC                 26
# ND                  1
# NE                  8
# NH                  2
# NJ                 33
# NV                  9
# NY                 93
# OH                 57
# OK                 10
# OR                  5
# PA                 42
# RI                  7
# SC                  5
# TN                 23
# TX                 94
# UT                  4
# VA                 38
# VT                  1
# WA                 20
# WI                 22

# %%
fortune_mean = fortune_group["Revenue as Int"].mean()
mean_df = pd.DataFrame(fortune_mean)
mean_df
# Out:
#              Revenue as Int
# State
# AL              4651.466667
# AR             71746.875000
# AZ              6149.411765
# CA             14922.652542
# CO              7440.315789
# CT             13847.222222
# DE              5681.000000
# FL              9397.025714
# GA             14390.233333
# HI              2433.000000
# IA              5963.666667
# ID             28144.000000
# IL             13901.100000
# IN             11762.470588
# KS              4072.666667
# KY              9284.666667
# LA             10506.333333
# MA             12412.531250
# MD              9778.666667
# ME              1969.000000
# MI             20732.428571
# MN             22332.920000
# MO             11784.434783
# MS              3342.000000
# NC             12517.923077
# ND              4444.000000
# NE             36616.375000
# NH              2883.500000
# NJ             13188.909091
# NV              5423.888889
# NY             16296.639785
# OH             13076.494737
# OK              6944.700000
# OR             10216.200000
# PA             12694.285714
# Puerto Rico     2530.500000
# RI             32481.000000
# SC              4336.400000
# TN             11902.043478
# TX             15934.510638
# UT              2691.500000
# VA             10701.105263
# VT              2275.000000
# WA             32088.250000
# WI              6973.381818

# %%
mean_df = mean_df.drop(["Puerto Rico"], axis=0)
mean_df
# Out:
#        Revenue as Int
# State
# AL        4651.466667
# AR       71746.875000
# AZ        6149.411765
# CA       14922.652542
# CO        7440.315789
# CT       13847.222222
# DE        5681.000000
# FL        9397.025714
# GA       14390.233333
# HI        2433.000000
# IA        5963.666667
# ID       28144.000000
# IL       13901.100000
# IN       11762.470588
# KS        4072.666667
# KY        9284.666667
# LA       10506.333333
# MA       12412.531250
# MD        9778.666667
# ME        1969.000000
# MI       20732.428571
# MN       22332.920000
# MO       11784.434783
# MS        3342.000000
# NC       12517.923077
# ND        4444.000000
# NE       36616.375000
# NH        2883.500000
# NJ       13188.909091
# NV        5423.888889
# NY       16296.639785
# OH       13076.494737
# OK        6944.700000
# OR       10216.200000
# PA       12694.285714
# RI       32481.000000
# SC        4336.400000
# TN       11902.043478
# TX       15934.510638
# UT        2691.500000
# VA       10701.105263
# VT        2275.000000
# WA       32088.250000
# WI        6973.381818

# %%
merged_df = pd.merge(state_df, math_df, on="State")
merged_df = merged_df.rename(columns={"Revenue as Int":"Number of F100 Company", "Mean_wage_yr":"Average Wage"})
merged_df["Region"] = ""
merged_df = merged_df.set_index("State")
merged_df
# Out:
#        Number of F100 Company  Average Wage Region
# State
# AL                          3         84290
# AR                          8         68290
# AZ                         17         83140
# CA                        118        108190
# CO                         19         96880
# CT                         27         92590
# DE                          2         93550
# FL                         35         78780
# GA                         30         88590
# HI                          3         80570
# IA                          6         78720
# ID                          3         71910
# IL                         70         87720
# IN                         17         75100
# KS                          6         73230
# KY                          9         70890
# LA                          3         66850
# MA                         32         98630
# MD                         12        100560
# ME                          1         77440
# MI                         28         79280
# MN                         25         87350
# MO                         23         78420
# MS                          1         69920
# NC                         26         87630
# ND                          1         69350
# NE                          8         77270
# NH                          2         93680
# NJ                         33        101390
# NV                          9         78960
# NY                         93         97320
# OH                         57         82080
# OK                         10         71540
# OR                          5         85140
# PA                         42         84800
# RI                          7         88020
# SC                          5         74030
# TN                         23         75310
# TX                         94         90740
# UT                          4         81740
# VA                         38        102430
# VT                          1         75920
# WA                         20        108660
# WI                         22         77080

# %%
west = ["WA", "OR", "NV", "ID", "MT", "WY", "UT", "CO", "HI", "AL", "CA"]
midwest = ["ND", "SD", "NE", "KS", "MN", "IA", "MO", "WI", "IL", "MI", "IN", "OH"]
northeast = ["PA", "MD", "DE", "NJ", "CT", "RI", "MA", "NH", "VT", "ME", "NY"]
southeast = ["AR", "LA", "MS", "TN", "KY", "WV", "VA", "NC", "SC", "GA", "AL","FL"]
southwest = ["AZ","NM","OK", "TX"]

for index, row in merged_df.iterrows():
    if index in west:
        merged_df.loc[index,"Region"] = "West"
    elif index in midwest:
        merged_df.loc[index,"Region"] = "Midwest"
    elif index in northeast:
        merged_df.loc[index,"Region"] = "Northeast"
    elif index in southeast:
        merged_df.loc[index,"Region"] = "Southeast"
    elif index in southwest:
        merged_df.loc[index,"Region"] = "Southwest"

merged_df
# Out:
#        Number of F100 Company  Average Wage     Region
# State
# AL                          3         84290       West
# AR                          8         68290  Southeast
# AZ                         17         83140  Southwest
# CA                        118        108190       West
# CO                         19         96880       West
# CT                         27         92590  Northeast
# DE                          2         93550  Northeast
# FL                         35         78780  Southeast
# GA                         30         88590  Southeast
# HI                          3         80570       West
# IA                          6         78720    Midwest
# ID                          3         71910       West
# IL                         70         87720    Midwest
# IN                         17         75100    Midwest
# KS                          6         73230    Midwest
# KY                          9         70890  Southeast
# LA                          3         66850  Southeast
# MA                         32         98630  Northeast
# MD                         12        100560  Northeast
# ME                          1         77440  Northeast
# MI                         28         79280    Midwest
# MN                         25         87350    Midwest
# MO                         23         78420    Midwest
# MS                          1         69920  Southeast
# NC                         26         87630  Southeast
# ND                          1         69350    Midwest
# NE                          8         77270    Midwest
# NH                          2         93680  Northeast
# NJ                         33        101390  Northeast
# NV                          9         78960       West
# NY                         93         97320  Northeast
# OH                         57         82080    Midwest
# OK                         10         71540  Southwest
# OR                          5         85140       West
# PA                         42         84800  Northeast
# RI                          7         88020  Northeast
# SC                          5         74030  Southeast
# TN                         23         75310  Southeast
# TX                         94         90740  Southwest
# UT                          4         81740       West
# VA                         38        102430  Southeast
# VT                          1         75920  Northeast
# WA                         20        108660       West
# WI                         22         77080    Midwest

# %%
region_group = merged_df.groupby("Region")
region_average = region_group["Average Wage"].mean()
region_companies = region_group["Number of F100 Company"].sum()
region_df = pd.DataFrame(region_companies)
region_df["Average Wage"] = region_average
region_df
# Out:
#            Number of F100 Company  Average Wage
# Region
# Midwest                       263  78690.909091
# Northeast                     252  91263.636364
# Southeast                     178  78272.000000
# Southwest                     121  81806.666667
# West                          184  88482.222222

# %%
fig, ax = plt.subplots()
# x_axis = reformat_df.index

# fig.suptitle("Density of Successful Companies (per State) vs Average Wage of Computational Employees", fontsize=10, fontweight="bold")
title = ax.set_title("\n".join(wrap("Density of Successful Companies (per State) vs Average Wage of Computational Employees", 60)), fontweight="bold")

ax.set_xlabel("Number of Fortune 1000 Companies per State")
ax.set_ylabel("Average Wage of Computational Employees")

# ax.set_ylim(30,75)
ax.grid()

ax.scatter(merged_df["Number of F100 Company"], merged_df["Average Wage"], marker="o", color = "r")
# (slope, intercept, _,_,_) = linregress(merged_df["Number of F100 Company"], merged_df["Average Revenue"])
# line = slope * merged_df["Number of F100 Company"] + intercept
# ax.plot(merged_df["Number of F100 Company"], line, "r--")
# capomulin, = ax.plot(x_axis, reformat_df["Capomulin"], "r--", marker="o",linewidth=1)

plt.savefig("Images/f100perstate_vs_avgwage.png")
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
fig, ax = plt.subplots()
# x_axis = reformat_df.index

fig.suptitle("Average Wage of Computational Employees per Region", fontsize=14, fontweight="bold")
# title = ax.set_title("\n".join(wrap("Density of Successful Companies (per Region) vs Average Wage of Computational Employees", 60)), fontweight="bold")
# ax.set_xlabel("Number of Fortune 500 Companies per Region")
ax.set_ylabel("Average Wage of Computation Employees")

# ax.set_ylim(30,75)
# ax.grid()

ax.bar(region_df.index, region_df["Average Wage"])
# (slope, intercept, _,_,_) = linregress(region_df["Number of F100 Company"], region_df["Average Revenue"])
# line = slope * region_df["Number of F100 Company"] + intercept
# ax.plot(region_df["Number of F100 Company"], line, "r--")
# capomulin, = ax.plot(x_axis, reformat_df["Capomulin"], "r--", marker="o",linewidth=1)

plt.savefig("Images/regional_avgwage.png")
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
state_df_sort = state_df.sort_values("Revenue as Int", ascending = False)
state_df_sort = state_df_sort.head()
state_df_sort
# Out:
#        Revenue as Int
# State
# CA                118
# TX                 94
# NY                 93
# IL                 70
# OH                 57

# %%
fig, ax = plt.subplots()
# x_axis = reformat_df.index

fig.suptitle("Top 5 States with Most Fortune 1000 Companies", fontsize=14, fontweight="bold")
# ax.set_xlabel("Number of Fortune 500 Companies per State")
ax.set_ylabel("Number of Fortune 100 Companies")

# ax.set_ylim(30,75)
# ax.grid()

ax.bar(state_df_sort.index, state_df_sort["Revenue as Int"])
plt.savefig("Images/top5stateswithmostf100.png")
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
west_df = merged_df.loc[merged_df["Region"] == "West", :]
midwest_df = merged_df.loc[merged_df["Region"] == "Midwest", :]
northeast_df = merged_df.loc[merged_df["Region"] == "Northeast", :]
southeast_df = merged_df.loc[merged_df["Region"] == "Southeast", :]
southwest_df = merged_df.loc[merged_df["Region"] == "Southwest", :]

west_df
# Out:
#        Number of F100 Company  Average Wage Region
# State
# AL                          3         84290   West
# CA                        118        108190   West
# CO                         19         96880   West
# HI                          3         80570   West
# ID                          3         71910   West
# NV                          9         78960   West
# OR                          5         85140   West
# UT                          4         81740   West
# WA                         20        108660   West

# %%
fig, ax = plt.subplots()

title = ax.set_title("\n".join(wrap("Density of Successful Companies (per State) vs Average Wage of Computational Employees", 60)), fontweight="bold")

ax.set_xlabel("Number of Fortune 1000 Companies per State")
ax.set_ylabel("Average Wage of Computational Employees")

ax.grid()

west_plot = ax.scatter(west_df["Number of F100 Company"], west_df["Average Wage"], marker="o", label = "West")
midwest_plot = ax.scatter(midwest_df["Number of F100 Company"], midwest_df["Average Wage"], marker="o", label = "Midwest")
northeast_plot = ax.scatter(northeast_df["Number of F100 Company"], northeast_df["Average Wage"], marker="o", label = "Northeast")
southeast_plot = ax.scatter(southeast_df["Number of F100 Company"], southeast_df["Average Wage"], marker="o", label = "Southeast")
southwest_plot = ax.scatter(southwest_df["Number of F100 Company"], southwest_df["Average Wage"], marker="o", label = "Southwest")

ax.legend(fontsize='small')


plt.savefig("Images/f100perstate_vs_avgwage_perregion.png")
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
f_oneway(west_df["Average Wage"], midwest_df["Average Wage"], northeast_df["Average Wage"], southeast_df["Average Wage"], southwest_df["Average Wage"])
# Out:
# F_onewayResult(statistic=3.637958367079861, pvalue=0.012999250758923213)

# %%
# ----------------------------------------------------------------------------------------------------------
