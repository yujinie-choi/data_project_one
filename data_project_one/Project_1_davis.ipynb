# %%
#imports
from matplotlib import pyplot as plt
import numpy as np
import pandas as pd

# %%
#path for Data Science job data

ds_jobs_csv = "../Resources/alldata.csv"

# %%
#creating a pandfas data frame

DS_jobs_pd = pd.read_csv(ds_jobs_csv)
DS_jobs_pd = DS_jobs_pd[["position", "company", "location"]]

# %%
#DS_jobs_pd["location"].unique()

# %%
grouped_ds_df = DS_jobs_pd.groupby("company")
grouped_ds_df.count()
# Out:
#                                    position  location
# company
# 10x Genomics                              1         1
# 1199SEIU Family of Funds                  1         1
# 1871                                      1         1
# 23andMe                                  17        17
# 24 Hour Fitness                           1         1
# 2M Research Services                      1         1
# 2U                                        1         1
# 2rbConsulting                             2         2
# 3D Systems                                1         1
# 3Q Digital                                1         1
# 605                                       1         1
# 6sense                                    1         1
# 7Cups                                     1         1
# 7Park Data                                3         3
# 84.51°                                    3         3
# A Place for Mom                           2         2
# ...
